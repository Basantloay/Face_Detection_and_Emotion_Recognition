# %%
from commonfunctions import *
from skimage import io
from skimage.color import rgb2gray
import matplotlib.pyplot as plt
import os
import numpy as np
import argparse
import cv2

# %%
# Get user supplied values
imagePath = "p1.png"


# Create the haar cascade

faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
# Read the image
image1= io.imread(imagePath)

image = cv2.imread(imagePath)

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Detect faces in the image
faces = faceCascade.detectMultiScale(gray,scaleFactor=1.1,minNeighbors=5,minSize=(30, 30),flags = cv2.CASCADE_SCALE_IMAGE)

#print("Found {0} faces!").format(len(faces))

# Draw a rectangle around the faces
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)
    
show_images([image1,image],["Original Image","Faces found"])

# %%
from fer import FER
import matplotlib.pyplot as plt 
img = plt.imread(imagePath)
detector = FER(mtcnn=True)
print(detector.detect_emotions(img))
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\BASANT~1\AppData\Local\Temp/ipykernel_13472/401378601.py in <module>
# ----> 1 from fer import FER
#       2 import matplotlib.pyplot as plt
#       3 img = plt.imread(imagePath)
#       4 detector = FER(mtcnn=True)
#       5 print(detector.detect_emotions(img))
#
# ModuleNotFoundError: No module named 'fer'
